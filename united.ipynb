# %% [markdown]
# # Create a Local Ethernet (Layer 2) Network
#
# This notebook shows how to create an isolated local Ethernet and connect compute nodes to it.

# %% [markdown]
# ## Import the FABlib Library

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

try:
    fablib = fablib_manager()
                         
    fablib.show_config()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_5266e tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_5266e tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5266e caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_5266e_row0_col0, #T_5266e_row0_col1, #T_5266e_row1_col0, #T_5266e_row1_col1, #T_5266e_row2_col0, #T_5266e_row2_col1, #T_5266e_row3_col0, #T_5266e_row3_col1, #T_5266e_row4_col0, #T_5266e_row4_col1, #T_5266e_row5_col0, #T_5266e_row5_col1, #T_5266e_row6_col0, #T_5266e_row6_col1, #T_5266e_row7_col0, #T_5266e_row7_col1, #T_5266e_row8_col0, #T_5266e_row8_col1, #T_5266e_row9_col0, #T_5266e_row9_col1, #T_5266e_row10_col0, #T_5266e_row10_col1, #T_5266e_row11_col0, #T_5266e_row11_col1, #T_5266e_row12_col0, #T_5266e_row12_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_5266e">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5266e_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_5266e_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_5266e_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_5266e_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_5266e_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_5266e_row2_col1" class="data row2 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_5266e_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_5266e_row3_col1" class="data row3 col1" >f8a6e0b0-ad14-47cb-9764-74c20ef3e4fc</td>
#     </tr>
#     <tr>
#       <td id="T_5266e_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_5266e_row4_col1" class="data row4 col1" >durbek_gafurov_0000000854</td>
#     </tr>
#     <tr>
#       <td id="T_5266e_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_5266e_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/bastionD</td>
#     </tr>
#     <tr>
#       <td id="T_5266e_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_5266e_row6_col1" class="data row6 col1" >bastion-1.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_5266e_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_5266e_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_5266e_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_5266e_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/.ssh/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_5266e_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_5266e_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/.ssh/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_5266e_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_5266e_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_5266e_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_5266e_row11_col1" class="data row11 col1" >/home/fabric/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_5266e_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_5266e_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## (Optional): Query for Available Testbed Resources and Settings
#
# This optional command queries the FABRIC services to find the available resources. It may be useful for finding a site with available capacity.

# %%
try:
    print(f"{fablib.list_sites()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_1e99d caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_1e99d th {
#   text-align: left;
# }
# #T_1e99d tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_1e99d tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_1e99d .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_1e99d_row0_col0, #T_1e99d_row0_col1, #T_1e99d_row0_col2, #T_1e99d_row0_col3, #T_1e99d_row0_col4, #T_1e99d_row0_col5, #T_1e99d_row0_col6, #T_1e99d_row0_col7, #T_1e99d_row0_col8, #T_1e99d_row0_col9, #T_1e99d_row0_col10, #T_1e99d_row0_col11, #T_1e99d_row0_col12, #T_1e99d_row0_col13, #T_1e99d_row0_col14, #T_1e99d_row0_col15, #T_1e99d_row0_col16, #T_1e99d_row0_col17, #T_1e99d_row0_col18, #T_1e99d_row0_col19, #T_1e99d_row0_col20, #T_1e99d_row0_col21, #T_1e99d_row0_col22, #T_1e99d_row0_col23, #T_1e99d_row0_col24, #T_1e99d_row0_col25, #T_1e99d_row0_col26, #T_1e99d_row0_col27, #T_1e99d_row0_col28, #T_1e99d_row0_col29, #T_1e99d_row0_col30, #T_1e99d_row0_col31, #T_1e99d_row1_col0, #T_1e99d_row1_col1, #T_1e99d_row1_col2, #T_1e99d_row1_col3, #T_1e99d_row1_col4, #T_1e99d_row1_col5, #T_1e99d_row
, #T_1e99d_row4_col20, #T_1e99d_row4_col21, #T_1e99d_row4_col22, #T_1e99d_row4_col23, #T_1e99d_row4_col24, #T_1e99d_row4_col25, #T_1e99d_row4_col26, #T_1e99d_row4_col27, #T_1e99d_row4_col28, #T_1e99d_row4_col29, #T_1e99d_row4_col30, #T_1e99d_row4_col31, #T_1e99d_row5_col0, #T_1e99d_row5_col1, #T_1e99d_row5_col2, #T_1e99d_row5_col3, #T_1e99d_row5_col4, #T_1e99d_row5_col5, #T_1e99d_row5_col6, #T_1e99d_row5_col7, #T_1e99d_row5_col8, #T_1e99d_row5_col9, #T_1e99d_row5_col10, #T_1e99d_row5_col11, #T_1e99d_row5_col12, #T_1e99d_row5_col13, #T_1e99d_row5_col14, #T_1e99d_row5_col15, #T_1e99d_row5_col16, #T_1e99d_row5_col17, #T_1e99d_row5_col18, #T_1e99d_row5_col19, #T_1e99d_row5_col20, #T_1e99d_row5_col21, #T_1e99d_row5_col22, #T_1e99d_row5_col23, #T_1e99d_row5_col24, #T_1e99d_row5_col25, #T_1e99d_row5_col26, #T_1e99d_row5_col27, #T_1e99d_row5_col28, #T_1e99d_row5_col29, #T_1e99d_row5_col30, #T_1e99d_row5_col31, #T_1e99d_row6_col0, #T_1e99d ...
# <pandas.io.formats.style.Styler object at 0x7fafff80edf0>

# %% [markdown]
# ## Create the Experiment Slice
#
# The following creates two nodes with basic NICs connected to an isolated local Ethernet.
#
# Two nodes are created and one NIC component is added to each node.  This example uses components of model `NIC_Basic` which are SR-IOV Virtual Function on a 100 Gpbs Mellanox ConnectX-6 PCI device. The VF is accessed by the node via PCI passthrough. Other NIC models are listed below. When using dedicated PCI devices the whole physical device is allocated to one node and the device is accessed by the node using PCI passthrough. Calling the `get_interfaces()` method on a component will return a list of interfaces. Many dedicated NIC components may have more than one port.  Either port can be connected to the network.
#
# Next, add an `l2network` to the slice and pass the list of interfaces you want connected to this Ethernet. If all interfaces in the list are located on the same site, the network will automatically be a local Ethernet.  By default, a node is put on a random site.  If you want to ensure that your nodes are all on the same site you can specify the name of the site in the `add_node` methode.  You can use the `fablib.get_random_site()` method to get a random site name that can be used for both nodes.
#
# NIC component models options:
# - NIC_Basic: 100 Gbps Mellanox ConnectX-6 SR-IOV VF (1 Port)
# - NIC_ConnectX_5: 25 Gbps Dedicated Mellanox ConnectX-5 PCI Device (2 Ports)
# - NIC_ConnectX_6: 100 Gbps Dedicated Mellanox ConnectX-6 PCI Device (2 Ports)

# %%
slice_name = 'Experiment 1.2'

site1 = 'GPN'  
site2 = 'SALT'

node1_name = 'Node1'
node2_name = 'Node2'
node3_name = 'Node3'
network1_2_name='net1_2'
network2_3_name='net2_3'
node1_nic_name = 'nic1'
node2_1_nic_name = 'nic2_1'
node2_3_nic_name = 'nic2_3'
node3_nic_name = 'nic3'
image='default_ubuntu_20'

cores = 2
ram = 8
disk = 10

# %%
try:
    #Create Slice
    slice = fablib.new_slice(name=slice_name)

    # Node1
    node1 = slice.add_node(name=node1_name, site=site1, cores=cores, ram=ram, disk=disk)
    iface1 = node1.add_component(model='NIC_Basic', name=node1_nic_name).get_interfaces()[0]
    node1.set_image(image)
    
    # Node2
    node2 = slice.add_node(name=node2_name, site=site1, cores=cores, ram=ram, disk=disk)
    iface2_1 = node2.add_component(model='NIC_Basic', name=node2_1_nic_name).get_interfaces()[0]
    iface2_3 = node2.add_component(model='NIC_Basic', name=node2_3_nic_name).get_interfaces()[0]
    node2.set_image(image)

    # Node3
    node3 = slice.add_node(name=node3_name, site=site2, cores=cores, ram=ram, disk=disk)
    iface3 = node3.add_component(model='NIC_Basic', name=node3_nic_name).get_interfaces()[0]
    node3.set_image(image)
    
    # Network
    net1_2 = slice.add_l2network(name=network1_2_name, interfaces=[iface1, iface2_1])
    net2_3 = slice.add_l2network(name=network2_3_name, interfaces=[iface2_3, iface3])

    #Submit Slice Request
    slice.submit()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Retry: 7, Time: 1641 sec
# <style type="text/css">
# #T_74d52 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_74d52 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_74d52 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_74d52_row0_col0, #T_74d52_row0_col1, #T_74d52_row1_col0, #T_74d52_row1_col1, #T_74d52_row2_col0, #T_74d52_row2_col1, #T_74d52_row3_col0, #T_74d52_row3_col1, #T_74d52_row4_col0, #T_74d52_row4_col1, #T_74d52_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_74d52_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_74d52">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_74d52_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_74d52_row0_col1" class="data row0 col1" >77faa968-0460-4733-8882-a3d67dc1d8d0</td>
#     </tr>
#     <tr>
#       <td id="T_74d52_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_74d52_row1_col1" class="data row1 col1" >Experiment 1.2</td>
#     </tr>
#     <tr>
#       <td id="T_74d52_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_74d52_row2_col1" class="data row2 col1" >2023-01-10 17:20:24 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_74d52_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_74d52_row3_col1" class="data row3 col1" >2023-01-09 17:20:25 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_74d52_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_74d52_row4_col1" class="data row4 col1" >f8a6e0b0-ad14-47cb-9764-74c20ef3e4fc</td>
#     </tr>
#     <tr>
#       <td id="T_74d52_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_74d52_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e153a caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_e153a th {
#   text-align: left;
# }
# #T_e153a tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e153a tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_e153a .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e153a_row0_col0, #T_e153a_row0_col1, #T_e153a_row0_col2, #T_e153a_row0_col3, #T_e153a_row0_col4, #T_e153a_row0_col5, #T_e153a_row0_col6, #T_e153a_row0_col7, #T_e153a_row0_col8, #T_e153a_row0_col9, #T_e153a_row0_col10, #T_e153a_row0_col13, #T_e153a_row0_col14, #T_e153a_row0_col15, #T_e153a_row1_col0, #T_e153a_row1_col1, #T_e153a_row1_col2, #T_e153a_row1_col3, #T_e153a_row1_col4, #T_e153a_row1_col5, #T_e153a_row1_col6, #T_e153a_row1_col7, #T_e153a_row1_col8, #T_e153a_row1_col9, #T_e153a_row1_col10, #T_e153a_row1_col13, #T_e153a_row1_col14, #T_e153a_row1_col15, #T_e153a_row2_col0, #T_e153a_row2_col1, #T_e153a_row2_col2, #T_e153a_row2_col3, #T_e153a_row2_col4, #T_e153a_row2_col5, #T_e153a_row2_col6, #T_e153a_row2_col7, #T_e153a_row2_col8, #T_e153a_row2_col9, #T_e153a_row2_col10, #T_e153a_row2_col13, #T_e153a_row2_col14, #T_e153a_row2_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T
tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b6920 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_b6920 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b6920_row0_col0, #T_b6920_row0_col1, #T_b6920_row0_col2, #T_b6920_row0_col3, #T_b6920_row0_col4, #T_b6920_row0_col5, #T_b6920_row0_col6, #T_b6920_row1_col0, #T_b6920_row1_col1, #T_b6920_row1_col2, #T_b6920_row1_col3, #T_b6920_row1_col4, #T_b6920_row1_col5, #T_b6920_row1_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_b6920_row0_col7, #T_b6920_row1_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_b6920_row0_col8, #T_b6920_row1_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_b6920">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_b6920_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_b6920_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_b6920_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_b6920_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_b6920_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_b6920_level0_col5" class="col_heading level0 col5" >Gateway</th>
#       <th id="T_b6920_level0_col6" class="col_heading level0 col6" >Subnet</th>
#       <th id="T_b6920_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_b6920_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b6920_row0_col0" class="data row0 col0" >42cf3d96-6841-4d77-a164-3e531e4eab0e</td>
#       <td id="T_b6920_row0_col1" class="data row0 col1" >net1_2</td>
#       <td id="T_b6920_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_b6920_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_b6920_row0_col4" class="data row0 col4" >GPN</td>
#       <td id="T_b6920_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_b6920_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_b6920_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_b6920_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_b6920_row1_col0" class="data row1 col0" >a69264a2-9678-4716-b54a-5a4a44e72bfe</td>
#       <td id="T_b6920_row1_col1" class="data row1 col1" >net2_3</td>
#       <td id="T_b6920_row1_col2" class="data row1 col2" >L2</td>
#       <td id="T_b6920_row1_col3" class="data row1 col3" >L2STS</td>
#       <td id="T_b6920_row1_col4" class="data row1 col4" >None</td>
#       <td id="T_b6920_row1_col5" class="data row1 col5" >None</td>
#       <td id="T_b6920_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_b6920_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_b6920_row1_col8" class="data row1 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# Time to stable 1641 seconds
# Running post_boot_config ... Time to post boot config 2127 seconds
# <style type="text/css">
# #T_dfe81 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_dfe81 th {
#   text-align: left;
# }
# #T_dfe81 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_dfe81 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_dfe81 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_dfe81_row0_col0, #T_dfe81_row0_col1, #T_dfe81_row0_col2, #T_dfe81_row0_col3, #T_dfe81_row0_col4, #T_dfe81_row0_col5, #T_dfe81_row0_col6, #T_dfe81_row0_col7, #T_dfe81_row1_col0, #T_dfe81_row1_col1, #T_dfe81_row1_col2, #T_dfe81_row1_col3, #T_dfe81_row1_col4, #T_dfe81_row1_col5, #T_dfe81_row1_col6, #T_dfe81_row1_col7, #T_dfe81_row2_col0, #T_dfe81_row2_col1, #T_dfe81_row2_col2, #T_dfe81_row2_col3, #T_dfe81_row2_col4, #T_dfe81_row2_col5, #T_dfe81_row2_col6, #T_dfe81_row2_col7, #T_dfe81_row3_col0, #T_dfe81_row3_col1, #T_dfe81_row3_col2, #T_dfe81_row3_col3, #T_dfe81_row3_col4, #T_dfe81_row3_col5, #T_dfe81_row3_col6, #T_dfe81_row3_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_dfe81">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_dfe81_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_dfe81_level0_col1" class="col_heading level0 col1" >Node</th>
#       <th id="T_dfe81_level0_col2" class="col_heading level0 col2" >Network</th>
#       <th id="T_dfe81_level0_col3" class="col_heading level0 col3" >Bandwidth</th>
#       <th id="T_dfe81_level0_col4" class="col_heading level0 col4" >VLAN</th>
#       <th id="T_dfe81_level0_col5" class="col_heading level0 col5" >MAC</th>
#       <th id="T_dfe81_level0_col6" class="col_heading level0 col6" >Physical Device</th>
#       <th id="T_dfe81_level0_col7" class="col_heading level0 col7" >Device</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dfe81_row0_col0" class="data row0 col0" >Node1-nic1-p1</td>
#       <td id="T_dfe81_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_dfe81_row0_col2" class="data row0 col2" >net1_2</td>
#       <td id="T_dfe81_row0_col3" class="data row0 col3" >100</td>
#       <td id="T_dfe81_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_dfe81_row0_col5" class="data row0 col5" >2A:9D:B1:7B:81:8B</td>
#       <td id="T_dfe81_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_dfe81_row0_col7" class="data row0 col7" >None</td>
#     </tr>
#     <tr>
#       <td id="T_dfe81_row1_col0" class="data row1 col0" >Node2-nic2_3-p1</td>
#       <td id="T_dfe81_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_dfe81_row1_col2" class="data row1 col2" >net2_3</td>
#       <td id="T_dfe81_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_dfe81_row1_col4" class="data row1 col4" >None</td>
#       <td id="T_dfe81_row1_col5" class="data row1 col5" >2A:EF:9C:7A:A2:F0</td>
#       <td id="T_dfe81_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_dfe81_row1_col7" class="data row1 col7" >None</td>
#     </tr>
#     <tr>
#       <td id="T_dfe81_row2_col0" class="data row2 col0" >Node2-nic2_1-p1</td>
#       <td id="T_dfe81_row2_col1" class="data row2 col1" >Node2</td>
#       <td id="T_dfe81_row2_col2" class="data row2 col2" >net1_2</td>
#       <td id="T_dfe81_row2_col3" class="data row2 col3" >100</td>
#       <td id="T_dfe81_row2_col4" class="data row2 col4" >None</td>
#       <td id="T_dfe81_row2_col5" class="data row2 col5" >2E:22:4A:BF:30:75</td>
#       <td id="T_dfe81_row2_col6" class="data row2 col6" >None</td>
#       <td id="T_dfe81_row2_col7" class="data row2 col7" >None</td>
#     </tr>
#     <tr>
#       <td id="T_dfe81_row3_col0" class="data row3 col0" >Node3-nic3-p1</td>
#       <td id="T_dfe81_row3_col1" class="data row3 col1" >Node3</td>
#       <td id="T_dfe81_row3_col2" class="data row3 col2" >net2_3</td>
#       <td id="T_dfe81_row3_col3" class="data row3 col3" >100</td>
#       <td id="T_dfe81_row3_col4" class="data row3 col4" >None</td>
#       <td id="T_dfe81_row3_col5" class="data row3 col5" >06:39:79:DA:98:DF</td>
#       <td id="T_dfe81_row3_col6" class="data row3 col6" >None</td>
#       <td id="T_dfe81_row3_col7" class="data row3 col7" >None</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 2617 seconds

# %% [markdown]
# ## Observe the Slice's Attributes
#
# ### Print the slice

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    print(f"{slice}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -----------  ------------------------------------
# Slice Name   Experiment 1.2
# Slice ID     77faa968-0460-4733-8882-a3d67dc1d8d0
# Slice State  StableOK
# Lease End    2023-01-10 17:20:24 +0000
# -----------  ------------------------------------

# %% [markdown]
# ## Print the Node List

# %%
try:
    print(f"{slice.list_nodes()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_5cf07 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_5cf07 th {
#   text-align: left;
# }
# #T_5cf07 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5cf07 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_5cf07 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5cf07_row0_col0, #T_5cf07_row0_col1, #T_5cf07_row0_col2, #T_5cf07_row0_col3, #T_5cf07_row0_col4, #T_5cf07_row0_col5, #T_5cf07_row0_col6, #T_5cf07_row0_col7, #T_5cf07_row0_col8, #T_5cf07_row0_col9, #T_5cf07_row0_col10, #T_5cf07_row0_col11, #T_5cf07_row0_col12, #T_5cf07_row0_col13, #T_5cf07_row0_col14, #T_5cf07_row0_col15, #T_5cf07_row1_col0, #T_5cf07_row1_col1, #
row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_5cf07_row2_col7" class="data row2 col7" >salt-w1.fabric-testbed.net</td>
#       <td id="T_5cf07_row2_col8" class="data row2 col8" >SALT</td>
#       <td id="T_5cf07_row2_col9" class="data row2 col9" >ubuntu</td>
#       <td id="T_5cf07_row2_col10" class="data row2 col10" >2001:400:a100:3010:f816:3eff:fea8:d241</td>
#       <td id="T_5cf07_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_5cf07_row2_col12" class="data row2 col12" ></td>
#       <td id="T_5cf07_row2_col13" class="data row2 col13" >ssh -i /home/fabric/work/fabric_config/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3010:f816:3eff:fea8:d241</td>
#       <td id="T_5cf07_row2_col14" class="data row2 col14" >/home/fabric/work/fabric_config/.ssh/slice_key.pub</td>
#       <td id="T_5cf07_row2_col15" class="data row2 col15" >/home/fabric/work/fabric_config/.ssh/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# <pandas.io.formats.style.Styler object at 0x7faffc7c55b0>

# %% [markdown]
# ## Print the Node Details

# %%
try:
    for node in slice.get_nodes():
        print(f"{node}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -----------------  ------------------------------------------------------------------------------------------------------------------------------------------------
# ID                 5b18e743-ad1a-416a-aa10-ddc7d12c24c5
# Name               Node1
# Cores              2
# RAM                8
# Disk               10
# Image              default_ubuntu_20
# Image Type         qcow2
# Host               gpn-w4.fabric-testbed.net
# Site               GPN
# Management IP      2610:e0:a04c:fab2:f816:3eff:fe37:452a
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:e0:a04c:fab2:f816:3eff:fe37:452a
# -----------------  ------------------------------------------------------------------------------------------------------------------------------------------------
# -----------------  ------------------------------------------------------------------------------------------------------------------------------------------------
# ID                 90beb2c5-24a0-4265-b4ea-ac9e2bb4384a
# Name               Node2
# Cores              2
# RAM                8
# Disk               10
# Image              default_ubuntu_20
# Image Type         qcow2
# Host               gpn-w4.fabric-testbed.net
# Site               GPN
# Management IP      2610:e0:a04c:fab2:f816:3eff:fe25:5e74
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:e0:a04c:fab2:f816:3eff:fe25:5e74
# -----------------  ------------------------------------------------------------------------------------------------------------------------------------------------
# -----------------  -------------------------------------------------------------------------------------------------------------------------------------------------
# ID                 76146279-e215-454a-ac66-81ce61efbfe7
# Name               Node3
# Cores              2
# RAM                8
# Disk               10
# Image              default_ubuntu_20
# Image Type         qcow2
# Host               salt-w1.fabric-testbed.net
# Site               SALT
# Management IP      2001:400:a100:3010:f816:3eff:fea8:d241
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3010:f816:3eff:fea8:d241
# -----------------  -------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Print the Interfaces

# %%
try:    
    print(f"{slice.list_interfaces()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_14673 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_14673 th {
#   text-align: left;
# }
# #T_14673 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_14673 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_14673 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_14673_row0_col0, #T_14673_row0_col1, #T_14673_row0_col2, #T_14673_row0_col3, #T_14673_row0_col4, #T_14673_row0_col5, #T_14673_row0_col6, #T_14673_row0_col7, #T_14673_row1_col0, #T_14673_row1_col1, #T_14673_row1_col2, #T_14673_row1_col3, #T_14673_row1_col4, #T_14673_row1_col5, #T_14673_row1_col6, #T_14673_row1_col7, #T_14673_row2_col0, #T_14673_row2_col1, #T_14673_row2_col2, #T_14673_row2_col3, #T_14673_row2_col4, #T_14673_row2_col5, #T_14673_row2_col6, #T_14673_row2_col7, #T_14673_row3_col0, #T_14673_row3_col1, #T_14673_row3_col2, #T_14673_row3_col3, #T_14673_row3_col4, #T_14673_row3_col5, #T_14673_row3_col6, #T_14673_row3_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_14673">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_14673_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_14673_level0_col1" class="col_heading level0 col1" >Node</th>
#       <th id="T_14673_level0_col2" class="col_heading level0 col2" >Network</th>
#       <th id="T_14673_level0_col3" class="col_heading level0 col3" >Bandwidth</th>
#       <th id="T_14673_level0_col4" class="col_heading level0 col4" >VLAN</th>
#       <th id="T_14673_level0_col5" class="col_heading level0 col5" >MAC</th>
#       <th id="T_14673_level0_col6" class="col_heading level0 col6" >Physical Device</th>
#       <th id="T_14673_level0_col7" class="col_heading level0 col7" >Device</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_14673_row0_col0" class="data row0 col0" >Node1-nic1-p1</td>
#       <td id="T_14673_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_14673_row0_col2" class="data row0 col2" >net1_2</td>
#       <td id="T_14673_row0_col3" class="data row0 col3" >100</td>
#       <td id="T_14673_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_14673_row0_col5" class="data row0 col5" >2A:9D:B1:7B:81:8B</td>
#       <td id="T_14673_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_14673_row0_col7" class="data row0 col7" >None</td>
#     </tr>
#     <tr>
#       <td id="T_14673_row1_col0" class="data row1 col0" >Node2-nic2_3-p1</td>
#       <td id="T_14673_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_14673_row1_col2" class="data row1 col2" >net2_3</td>
#       <td id="T_14673_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_14673_row1_col4" class="data row1 col4" >None</td>
#       <td id="T_14673_row1_col5" class="data row1 col5" >2A:EF:9C:7A:A2:F0</td>
#       <td id="T_14673_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_14673_row1_col7" class="data row1 col7" >None</td>
#     </tr>
#     <tr>
#       <td id="T_14673_row2_col0" class="data row2 col0" >Node2-nic2_1-p1</td>
#       <td id="T_14673_row2_col1" class="data row2 col1" >Node2</td>
#       <td id="T_14673_row2_col2" class="data row2 col2" >net1_2</td>
#       <td id="T_14673_row2_col3" class="data row2 col3" >100</td>
#       <td id="T_14673_row2_col4" class="data row2 col4" >None</td>
#       <td id="T_14673_row2_col5" class="data row2 col5" >2E:22:4A:BF:30:75</td>
#       <td id="T_14673_row2_col6" class="data row2 col6" >None</td>
#       <td id="T_14673_row2_col7" class="data row2 col7" >None</td>
#     </tr>
#     <tr>
#       <td id="T_14673_row3_col0" class="data row3 col0" >Node3-nic3-p1</td>
#       <td id="T_14673_row3_col1" class="data row3 col1" >Node3</td>
#       <td id="T_14673_row3_col2" class="data row3 col2" >net2_3</td>
#       <td id="T_14673_row3_col3" class="data row3 col3" >100</td>
#       <td id="T_14673_row3_col4" class="data row3 col4" >None</td>
#       <td id="T_14673_row3_col5" class="data row3 col5" >06:39:79:DA:98:DF</td>
#       <td id="T_14673_row3_col6" class="data row3 col6" >None</td>
#       <td id="T_14673_row3_col7" class="data row3 col7" >None</td>
#     </tr>
#   </tbody>
# </table>
# <pandas.io.formats.style.Styler object at 0x7faffc757df0>

# %% [markdown]
# ## Prolong the lease

# %%
import datetime
end_date = (datetime.datetime.utcnow() + datetime.timedelta(days=36)).strftime("%Y-%m-%d %H:%M:%S %z")

try:
    slice.renew(end_date+"+0000")
    print(datetime.datetime.utcnow(),end_date+"+0000")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# 2023-01-09 18:45:35.868417 2023-02-14 18:45:30 +0000

# %% [markdown]
# ##  Configure IP Addresses
#
# Some experiments use FABRIC layer 2 networks to enable deploying non-IP layer 3 networks.  If this describes your experiment, your nodes and network are ready. You can now login to the nodes and deploy your experiment.
#
# Most users will want to configure IP addresses on their new nodes.  FABlib provides some useful methods to help you configure basic IP addresses.
#
# ### Pick a Subnet
#
# Create a subnet and list of available IP addresses. All objects are Python IP management objects. You can use either IPv4 or IPv6 subnets and addresses.

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network

try:
    subnet1 = IPv4Network("192.168.1.0/24")
    available_ips1 = list(subnet1)[1:]
    subnet2 = IPv4Network("192.168.2.0/24")
    available_ips2 = list(subnet2)[1:]
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### Configure Node1
#
# Get the node and the interface you wish to configure.  You can use `node.get_interface` to get the interface that is connected to the specified network.  Then `pop` an IP address from the list of available IPs and call `iface.ip_addr_add` to set the IP and subnet.
#
# Optionally, use the `node.execute()` method to show the results of adding the IP address.

# %%
try:
    node1 = slice.get_node(name=node1_name)        
    node1_iface = node1.get_interface(network_name=network1_2_name) 
    
    stdout, stderr = node1.execute('sudo apt install net-tools')
    print(stdout, stderr)
    stdout, stderr = node1.execute(f'sudo ifconfig {node1_iface.get_os_interface()} up')
    print(stdout, stderr)

    node1_addr = available_ips1.pop(0)
    node1_iface.ip_addr_add(addr=node1_addr, subnet=subnet1)
    
    stdout, stderr = node1.execute(f'ip addr show {node1_iface.get_os_interface()}')
    print (stdout)
    
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Exception: [Errno 99] Cannot assign requested address

# %% [markdown]
# ### Configure Node2
#
# Repeat the steps to add the next available IP to the second node.

# %%
try:
    node2 = slice.get_node(name=node2_name)        
    node2_1_iface = node2.get_interface(network_name=network1_2_name)  
    node2_1_addr = available_ips1.pop(0)
    node2_1_iface.ip_addr_add(addr=node2_1_addr, subnet=subnet1)
    
    stdout, stderr = node2.execute(f'ip addr show {node2_1_iface.get_os_interface()}')
    print (stdout)

    stdout, stderr = node2.execute('sudo apt install net-tools')
    print(stdout, stderr)
    stdout, stderr = node2.execute(f'sudo ifconfig {node2_1_iface.get_os_interface()} up')
    print(stdout, stderr)
    
    node2_3_iface = node2.get_interface(network_name=network2_3_name)  
    node2_3_addr = available_ips2.pop(0)
    node2_3_iface.ip_addr_add(addr=node2_3_addr, subnet=subnet2)
    
    stdout, stderr = node2.execute(f'sudo ifconfig {node2_3_iface.get_os_interface()} up')
    print(stdout, stderr)
    
    stdout, stderr = node2.execute(f'ip addr show {node2_3_iface.get_os_interface()}')
    print (stdout)

except Exception as e:
    print(f"Exception: {e}")
# Out:
# Exception: [Errno 99] Cannot assign requested address

# %% [markdown]
# ### Configure Node3
#
# Repeat the steps to add the next available IP to the third node.

# %%
try:
    node3 = slice.get_node(name=node3_name)        
    node3_iface = node3.get_interface(network_name=network2_3_name) 
    node3_addr = available_ips2.pop(0)
    node3_iface.ip_addr_add(addr=node3_addr, subnet=subnet2)

    stdout, stderr = node3.execute('sudo apt install net-tools')
    print(stdout, stderr)
    stdout, stderr = node3.execute(f'sudo ifconfig {node2_1_iface.get_os_interface()} up')
    print(stdout, stderr)
    
    stdout, stderr = node3.execute(f'ip addr show {node3_iface.get_os_interface()}')
    print (stdout)
    
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Exception: [Errno 99] Cannot assign requested address

# %%
node1 = slice.get_node(name=node1_name)
node2 = slice.get_node(name=node2_name) 
node3 = slice.get_node(name=node3_name)
node1_addr = "192.168.1.1"
node2_1_addr = "192.168.1.2"
node2_3_addr = "192.168.2.1"
node3_addr = "192.168.2.2"

# %% [markdown]
# ## Run the Experiment
#
# We will find the ping round trip time for this pair of sites.

# %%
try:
#     node1 = slice.get_node(name=node1_name)        

    stdout, stderr = node1.execute(f'ping -c 15 {node2_1_addr}')
    print (stdout)
    print (stderr)
    
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Exception: [Errno 99] Cannot assign requested address

# %%
try:
#     node1 = slice.get_node(name=node1_name)        

    stdout, stderr = node3.execute(f'ping -c 5 {node2_3_addr}')
    print (stdout)
    print (stderr)
    
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Exception: [Errno 99] Cannot assign requested address

# %%
try:
#     node1 = slice.get_node(name=node1_name)        

    stdout, stderr = node2.execute(f'ping -c 5 {node3_addr}')
    print (stdout)
    print (stderr)
    
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Exception: [Errno 99] Cannot assign requested address

# %% [markdown]
# ---

# %% [markdown]
# ## Installing iperf

# %%
config_threads = {}

config_threads[node1] = node1.execute(f'sudo apt update && sudo apt install -y iperf iperf3 ffmpeg')
config_threads[node2] = node2.execute(f'sudo apt update && sudo apt install -y iperf iperf3 ffmpeg')
config_threads[node3] = node3.execute(f'sudo apt update && sudo apt install -y iperf iperf3 ffmpeg')

for node, thread in config_threads.items():
    stdout, stderr = thread.result()
    print(f"Config thread node {node.get_name()} complete")
    print(stdout)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_83/3346656672.py in <module>
#       1 config_threads = {}
#       2
# ----> 3 config_threads[node1] = node1.execute(f'sudo apt update && sudo apt install -y iperf iperf3 ffmpeg')
#       4 config_threads[node2] = node2.execute(f'sudo apt update && sudo apt install -y iperf iperf3 ffmpeg')
#       5 config_threads[node3] = node3.execute(f'sudo apt update && sudo apt install -y iperf iperf3 ffmpeg')
#
# /opt/conda/lib/python3.9/site-packages/fabrictestbed_extensions/fablib/node.py in execute(self, command, retry, retry_interval, username, private_key_file, private_key_passphrase, quiet, read_timeout, timeout, output_file)
#    1276
#    1277                 if attempt+1 == retry:
# -> 1278                     raise e
#    1279
#    1280                 #Fail, try again
#
# /opt/conda/lib/python3.9/site-packages/fabrictestbed_extensions/fablib/node.py in execute(self, command, retry, retry_interval, username, private_key_file, private_key_passphrase, quiet, read_timeout, timeout, output_file)
#    1160                 bastion=paramiko.SSHClient()
#    1161                 bastion.set_missing_host_key_policy(paramiko.AutoAddPolicy())
# -> 1162                 bastion.connect(self.get_fablib_manager().get_bastion_public_addr(), username=bastion_username, key_filename=bastion_key_file)
#    1163
#    1164                 bastion_transport = bastion.get_transport()
#
# /opt/conda/lib/python3.9/site-packages/paramiko/client.py in connect(self, hostname, port, username, password, pkey, key_filename, timeout, allow_agent, look_for_keys, compress, sock, gss_auth, gss_kex, gss_deleg_creds, gss_host, banner_timeout, auth_timeout, gss_trust_dns, passphrase, disabled_algorithms, transport_factory)
#     356                         except:
#     357                             pass
# --> 358                     retry_on_signal(lambda: sock.connect(addr))
#     359                     # Break out of the loop on success
#     360                     break
#
# /opt/conda/lib/python3.9/site-packages/paramiko/util.py in retry_on_signal(function)
#     277     while True:
#     278         try:
# --> 279             return function()
#     280         except EnvironmentError as e:
#     281             if e.errno != errno.EINTR:
#
# /opt/conda/lib/python3.9/site-packages/paramiko/client.py in <lambda>()
#     356                         except:
#     357                             pass
# --> 358                     retry_on_signal(lambda: sock.connect(addr))
#     359                     # Break out of the loop on success
#     360                     break
#
# OSError: [Errno 99] Cannot assign requested address

# %%
# stdout, stderr = node1.execute(f'sudo apt update && sudo apt install -y iperf iperf3 ffmpeg')
# print (stdout)

# stdout, stderr = node2.execute(f'sudo apt update && sudo apt install -y iperf iperf3 ffmpeg')
# print (stdout)

# stdout, stderr = node3.execute(f'sudo apt update && sudo apt install -y iperf iperf3 ffmpeg')
# print (stdout)

# %% [markdown]
# ## Setting Parameters

# %%
stdout, stderr = node1.execute('echo "net.core.rmem_max = 2147483647\nnet.core.wmem_max = 2147483647\nnet.ipv4.tcp_rmem = 4096 87380 2147483647\nnet.ipv4.tcp_wmem = 4096 65536 2147483647\nnet.ipv4.tcp_congestion_control=htcp\nnet.ipv4.tcp_mtu_probing=1\nnet.core.default_qdisc = fq\n" | sudo tee -a /etc/sysctl.conf && sudo sysctl -p')
print (stdout)
print (stderr)

# %%
stdout, stderr = node2.execute('echo "net.core.rmem_max = 2147483647\nnet.core.wmem_max = 2147483647\nnet.ipv4.tcp_rmem = 4096 87380 2147483647\nnet.ipv4.tcp_wmem = 4096 65536 2147483647\nnet.ipv4.tcp_congestion_control=htcp\nnet.ipv4.tcp_mtu_probing=1\nnet.core.default_qdisc = fq\n" | sudo tee -a /etc/sysctl.conf && sudo sysctl -p')
print (stdout)
print (stderr)

# %%
stdout, stderr = node3.execute('echo "net.core.rmem_max = 2147483647\nnet.core.wmem_max = 2147483647\nnet.ipv4.tcp_rmem = 4096 87380 2147483647\nnet.ipv4.tcp_wmem = 4096 65536 2147483647\nnet.ipv4.tcp_congestion_control=htcp\nnet.ipv4.tcp_mtu_probing=1\nnet.core.default_qdisc = fq\n" | sudo tee -a /etc/sysctl.conf && sudo sysctl -p')
print (stdout)
print (stderr)

# %%
#server
stdout, stderr = node2.execute('tmux new -d \'iperf -s -f K\'') 
print (stdout)
print (stderr)

# %%
#client
stdout, stderr = node1.execute(f'iperf -c {node2_1_addr} -P 50 -w 999M') 
print (stdout)
print (stderr)

# %%
#client
stdout, stderr = node3.execute(f'iperf -c {node2_3_addr} -P 50 -w 999M') 
print (stdout)
print (stderr)

# %%
#client
stdout, stderr = node3.execute(f'iperf -c {node2_3_addr} -P 50 -w 999M') 
print (stdout)
print (stderr)

# %% [markdown]
# ## Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
# try:
#     slice = fablib.get_slice(name=slice_name)
#     slice.delete()
# except Exception as e:
#     print(f"Exception: {e}")
